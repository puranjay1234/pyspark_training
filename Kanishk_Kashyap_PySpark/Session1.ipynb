# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://8a805b1368dc:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = [('Kanishk','','Kashyap','2001-06-01','M',40000),
  ('harsh','s','','2000-08-19','M',40000)
]

columns = ["firstname","middlename","lastname","dob","gender","salary"]
df = spark.createDataFrame(data=data, schema = columns)
df.show()
# Out:
# +---------+----------+--------+----------+------+------+
# |firstname|middlename|lastname|       dob|gender|salary|
# +---------+----------+--------+----------+------+------+
# |  Kanishk|          | Kashyap|2001-06-01|     M| 40000|
# |    harsh|         s|        |2000-08-19|     M| 40000|
# +---------+----------+--------+----------+------+------+

# %%
path = "/content/sample_data/california_housing_test.csv"

df = spark.read.option("header",False).csv(path)
df.show()
# Out:
# +-----------+---------+------------------+-----------+--------------+-----------+----------+-------------+------------------+
# |        _c0|      _c1|               _c2|        _c3|           _c4|        _c5|       _c6|          _c7|               _c8|
# +-----------+---------+------------------+-----------+--------------+-----------+----------+-------------+------------------+
# |  longitude| latitude|housing_median_age|total_rooms|total_bedrooms| population|households|median_income|median_house_value|
# |-122.050000|37.370000|         27.000000|3885.000000|    661.000000|1537.000000|606.000000|     6.608500|     344700.000000|
# |-118.300000|34.260000|         43.000000|1510.000000|    310.000000| 809.000000|277.000000|     3.599000|     176500.000000|
# |-117.810000|33.780000|         27.000000|3589.000000|    507.000000|1484.000000|495.000000|     5.793400|     270500.000000|
# ...

# %%
df = spark.read.option('header','True').option("delimiter","|").csv("/content/sample.csv")
df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-4-2cdf5210505a> in <cell line: 1>()
# ----> 1 df = spark.read.option('header','True').option("delimiter","|").csv("/content/sample.csv")
#       2 df.show()
#
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     735             path = [path]
#     736         if type(path) == list:
# ...

# %%
df.printSchema()

# %%
df2 = df.withColumn("Name",df["Name"] .cast('Varchar(20)')).withColumn("Id",df["Id"] .cast('integer'))

df2.printSchema()

# %%
df=spark.read.option("delimiter","|").option("header","True").option("inferschema","True").csv("sample.csv")
df.show()
df.printSchema()

# %%
df= spark.read.parquet("/content/sample_data/MT cars.parquet")
df.printSchema()

# %%
df.schema

# %%
#JSON
from re import MULTILINE
readjson=spark.read.options(MULTILINE=True).json('/content/sample_data/anscombe.json')
readjson.show()
readjson.printSchema()
# Out:
# +------+----+-----+
# |Series|   X|    Y|
# +------+----+-----+
# |     I|10.0| 8.04|
# |     I| 8.0| 6.95|
# |     I|13.0| 7.58|
# |     I| 9.0| 8.81|
# |     I|11.0| 8.33|
# |     I|14.0| 9.96|
# |     I| 6.0| 7.24|
# |     I| 4.0| 4.26|
# |     I|12.0|10.84|
# |     I| 7.0| 4.81|
# |     I| 5.0| 5.68|
# |    II|10.0| 9.14|
# |    II| 8.0| 8.14|
# |    II|13.0| 8.74|
# |    II| 9.0| 8.77|
# |    II|11.0| 9.26|
# |    II|14.0|  8.1|
# |    II| 6.0| 6.13|
# |    II| 4.0|  3.1|
# |    II|12.0| 9.13|
# +------+----+-----+
# only showing top 20 rows
#
# root
#  |-- Series: string (nullable = true)
#  |-- X: double (nullable = true)
#  |-- Y: double (nullable = true)

# %%
#Operations

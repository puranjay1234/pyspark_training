# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://73cb92f79f17:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import logging
from math import log
# SparkSession.sparkContext.setLog
# Level("Error")
logging.getLogger().setLevel(logging.INFO)
# logging.basicConfig(level=logging.INFO)

# %%
def func():
  try:
    df1 = spark.read.format("csv").load("/content/CompleteDataset.csv",inferschema=True,header=True)
    # print(df1)
    # df1.show()
    logging.info("successfullycreated")
  except Exception as e:
    logging.error(f"An erroe occured:{str(e)}")

func()
# Out:
# INFO:root:successfullycreated
